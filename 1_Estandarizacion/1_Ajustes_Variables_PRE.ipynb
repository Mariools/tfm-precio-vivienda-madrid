# %%
#Se importan las librerias a utilizar

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import chardet

#Carga de datos PRE

with open("CasasEnVenta_Madrid_PRE.csv", "rb") as f:
    result = chardet.detect(f.read())
    encoding_detected = result["encoding"]

datos_pre = pd.read_csv("CasasEnVenta_Madrid_PRE.csv", encoding=encoding_detected, sep=';', index_col='id')
print(datos_pre.head(5))
# Out:
#      precio tipo_vivienda  metros_cuadrados_totales  metros_cuadrados_utiles  \
# id
# 1    650000          Piso                        78                     78.0
# 2    525000          Piso                        70                     62.0
# 3    795000          Piso                       127                    113.0
# 4   3650000          Piso                       304                    290.0
# 5   5100000         Ático                       310                    270.0
#
#    numero_baNos  numero_habitaciones                    estado  \
# id
# 1             1                    2  Segunda mano/buen estado
# 2             1                    1  Segunda mano/buen estado
# 3             2                    5  Segunda mano/buen estado
# 4             5                    4  Segunda mano/buen estado
# 5             5                    4  Segunda mano/buen estado
#
#    tipo_urbanizacion planta  interior  ...          terraza balcon jardin  \
# id                                     ...
# 1           Edificio      2  Exterior  ...               No     No     No
# 2           Edificio      4  Exterior  ...               No     Sí     No
# 3           Edificio      4  Exterior  ...               Sí     Sí     No
# 4           Edificio      5  Exterior  ...  No especificado     Sí     No
# 5           Edificio      6  Exterior  ...               Sí     No     No
#
#            armarios padel aire_acondicionado      calefaccion postal_code  \
# id
# 1   No especificado    No    No especificado  No especificado       28010
# 2   No especificado    No    No especificado  No especificado       28003
# 3                Sí    No    No especificado  No especificado       28003
# 4                Sí    No                 Sí              Gas       28010
# 5                Sí    No                 Sí       Individual       28008
#
#    geohash_6 municipio
# id
# 1     ezjq5b    Madrid
# 2     ezjq5c    Madrid
# 3     ezjq5e    Madrid
# 4     ezjq5b    Madrid
# 5     ezjmgq    Madrid
#
# [5 rows x 26 columns]

# %% [markdown]
# Como propuesta de calidad y gestión de datos, se han establecido los siguientes análisis:
#
# **0) Registro de meta-datos del dataset.**
#
# -Los tipos de datos por atributo.
#
# -El rango de valores que presenta.
#
# -Algunas características de los valores.
#
# -Dominio impuesto para cada atributo.
#
# **1) Evaluación de valores nulos.**
#
# **2) Evaluación de formato válido.**
#
# **3) Valores ajustados a los rangos del dominio.**
#
# **4) Claves únicas.**
#
# **5) Integridad referencial.**
#
# **6) Cumplimiento de reglas en valores.**

# %% [markdown]
# ## Análisis Datos PRE
#
# **0) Registro de meta-datos del dataset.**
#
# Se usa el método .info() para obtener datos crudos sobre los atributos del dataset y su contenido.

# %%
# Vista de los tipos de datos y el tamaño del dataset (filas/registros y columnas/atributos).

datos_pre.info()

print("-------------------------------------")
print(f"Cantidad de filas: {datos_pre.shape[0]}")
print(f"Cantidad de columnas: {datos_pre.shape[1]}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19253 entries, 1 to 19444
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   precio                    19253 non-null  int64
#  1   tipo_vivienda             19253 non-null  object
#  2   metros_cuadrados_totales  19253 non-null  int64
#  3   metros_cuadrados_utiles   19252 non-null  float64
#  4   numero_baNos              19253 non-null  object
#  5   numero_habitaciones       19253 non-null  int64
#  6   estado                    19253 non-null  object
#  7   tipo_urbanizacion         19253 non-null  object
#  8   planta                    19253 non-null  object
#  9   interior                  19253 non-null  object
#  10  orientacion               19253 non-null  object
#  11  aNo_contruccion           19096 non-null  object
#  12  ascensor                  19253 non-null  object
#  13  piscina                   19253 non-null  object
#  14  trastero                  19253 non-null  object
#  15  garaje                    19253 non-null  object
#  16  terraza                   19253 non-null  object
#  17  balcon                    19253 non-null  object
#  18  jardin                    19253 non-null  object
#  19  armarios                  19253 non-null  object
#  20  padel                     19253 non-null  object
#  21  aire_acondicionado        19253 non-null  object
#  22  calefaccion               19253 non-null  object
#  23  postal_code               19253 non-null  int64
#  24  geohash_6                 19253 non-null  object
#  25  municipio                 19253 non-null  object
# dtypes: float64(1), int64(4), object(21)
# memory usage: 4.0+ MB
# -------------------------------------
# Cantidad de filas: 19253
# Cantidad de columnas: 26

# %% [markdown]
# Para conocer los valores únicos por atributo y su distribución se usan los métodos .unique() y .value_counts()
#
# .unique(): lista las ocurrencias de valores únicos en el atributo.
#
# .value_counts(): por cada valor del atributo muestra la cantidad de filas que registran tal valor.
#
#
# **Tipos nominales (string)**

# %%
print(datos_pre.columns)
# Out:
# Index(['precio', 'tipo_vivienda', 'metros_cuadrados_totales',
#        'metros_cuadrados_utiles', 'numero_baNos', 'numero_habitaciones',
#        'estado', 'tipo_urbanizacion', 'planta', 'interior', 'orientacion',
#        'aNo_contruccion', 'ascensor', 'piscina', 'trastero', 'garaje',
#        'terraza', 'balcon', 'jardin', 'armarios', 'padel',
#        'aire_acondicionado', 'calefaccion', 'postal_code', 'geohash_6',
#        'municipio'],
#       dtype='object')

# %%
#Vista de los valores únicos para la variable "tipo_vivienda".

print(f"Valores presentes en el atributo: {datos_pre['tipo_vivienda'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['tipo_vivienda'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Piso' 'Ático' 'Dúplex' 'Estudio' 'Loft' 'Chalet' 'Chalet adosado'
#  'Chalet pareado' 'Casa de Pueblo' 'Finca Rústica' 'Casa rural' 'Sótano'
#  'Caserón']
#
# Conteo de ocurrencias por valor:
# tipo_vivienda
# Piso              12074
# Chalet             4372
# Ático               961
# Dúplex              826
# Estudio             367
# Chalet adosado      293
# Chalet pareado      112
# Finca Rústica        99
# Casa de Pueblo       82
# Loft                 31
# Casa rural           29
# Sótano                6
# Caserón               1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "estado".

print(f"Valores presentes en el atributo: {datos_pre['estado'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['estado'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Segunda mano/buen estado' 'Segunda mano/para reformar' 'Obra nueva'
#  'No especificado' 'segunda mano/buen estado' 'Promoción de obra nueva'
#  ' Segunda mano/buen estado' 'segunda mano/para reformar' 'obra nueva'
#  'Buena condición']
#
# Conteo de ocurrencias por valor:
# estado
# Segunda mano/buen estado      14694
# Segunda mano/para reformar     2445
# Obra nueva                     1491
# No especificado                 348
# segunda mano/buen estado        249
# segunda mano/para reformar       13
# obra nueva                        8
# Promoción de obra nueva           2
#  Segunda mano/buen estado         2
# Buena condición                   1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "tipo_urbanizacion".

print(f"Valores presentes en el atributo: {datos_pre['tipo_urbanizacion'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['tipo_urbanizacion'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Edificio' 'edificio' 'Casa/chalet unitaria' 'Vivienda unitaria'
#  'Casa/chalet de vivienda unitaria' 'Casa unitaria' 'Casa/chalet'
#  'Chalet pareado' 'Chalet adosado' 'Casa' 'casa/chalet'
#  'Casa independiente' 'Casa/chalet independiente' 'No especificado'
#  'Urbanización' 'casa/chalet de vivienda unitaria' 'Casa/Chalet'
#  'Casa o chalet independiente' 'vivienda unitaria' 'Chalet unifamiliar'
#  'Casa de vivienda unitaria' 'Urbanización privada'
#  'Urbanización en comunidad' 'Casa individual' 'Casa unifamiliar'
#  'Chalet de vivienda unitaria' 'Bajo exterior'
#  'Casa/Chalet de vivienda unitaria' 'Casa/chalet individual' 'Chalet'
#  'casa/chalet independiente' 'Casa/Chalet unitaria' 'casa/chalet unitaria'
#  'Casa/unidad' 'Unitaria' 'Casa/unidad independiente' 'urbanización'
#  'Casa chalet' 'urbanización en comunidad' 'Casa/chalet unitario']
#
# Conteo de ocurrencias por valor:
# tipo_urbanizacion
# Edificio                            14092
# Casa unitaria                        1585
# Casa/chalet de vivienda unitaria     1335
# Vivienda unitaria                     815
# Casa/chalet unitaria                  569
# Casa/chalet                           241
# edificio                              157
# Casa/chalet independiente              91
# Chalet pareado                         56
# Casa independiente                     53
# casa/chalet de vivienda unitaria       44
# Chalet adosado                         33
# casa/chalet                            31
# vivienda unitaria                      31
# Casa                                   25
# Urbanización                           15
# Casa/Chalet                            14
# No especificado                        12
# Chalet                                  8
# casa/chalet unitaria                    7
# Chalet unifamiliar                      4
# Chalet de vivienda unitaria             4
# Casa/Chalet unitaria                    3
# Bajo exterior                           3
# Casa/Chalet de vivienda unitaria        3
# urbanización                            2
# Casa/chalet individual                  2
# casa/chalet independiente               2
# Casa o chalet independiente             2
# Casa unifamiliar                        2
# Urbanización en comunidad               2
# Unitaria                                2
# Casa chalet                             1
# urbanización en comunidad               1
# Casa/unidad independiente               1
# Casa de vivienda unitaria               1
# Casa/unidad                             1
# Casa individual                         1
# Urbanización privada                    1
# Casa/chalet unitario                    1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "planta".

print(f"Valores presentes en el atributo: {datos_pre['planta'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['planta'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['2' '4' '5' '6' '8' 'Semi-sótano' '1' '12' '3' '9' '7' 'No especificado'
#  'Bajo' 'Entreplanta' '6ª' '2ª' '3ª' '12ª' '5ª' '-1' '0' '8ª' '1ª' '4ª'
#  '10ª' '2 plantas' '4 plantas' '16' '17' '10' '11' '20' '13' '14' '18'
#  '3 plantas' '15' '-2' 'Bajo interior' 'bajo' '11ª' '7ª' '9ª' '19' '13ª'
#  'Ático' 'ático' 'No aplica' '24' '22']
#
# Conteo de ocurrencias por valor:
# planta
# 1                  4428
# No especificado    3143
# 2                  2933
# Bajo               2123
# 3                  2008
# 4                  1544
# 5                   878
# 6                   554
# 7                   318
# 0                   289
# 3 plantas           146
# 8                   115
# 9                   112
# 1ª                  112
# Entreplanta         104
# Semi-sótano          65
# 4 plantas            49
# 10                   48
# 2 plantas            44
# 3ª                   37
# 11                   26
# 2ª                   24
# 12                   18
# -1                   16
# 13                   14
# Bajo interior        13
# 4ª                   10
# 6ª                    8
# 5ª                    7
# bajo                  7
# 14                    6
# 8ª                    6
# 15                    6
# 9ª                    5
# 10ª                   5
# 11ª                   4
# 12ª                   4
# 7ª                    3
# 22                    3
# -2                    3
# 16                    3
# 17                    2
# Ático                 2
# 18                    2
# 20                    1
# 19                    1
# 13ª                   1
# ático                 1
# No aplica             1
# 24                    1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "interior".

print(f"Valores presentes en el atributo: {datos_pre['interior'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['interior'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Exterior' 'Interior' 'interior' 'Sótano interior' 'No especificado'
#  'Externo' 'exterior' 'Bajo interior'
#  'Interior adaptado para personas con movilidad reducida' 'Exteriores']
#
# Conteo de ocurrencias por valor:
# interior
# Exterior                                                  12432
# No especificado                                            4974
# Interior                                                   1640
# exterior                                                    161
# interior                                                     25
# Interior adaptado para personas con movilidad reducida        8
# Sótano interior                                               5
# Externo                                                       5
# Bajo interior                                                 2
# Exteriores                                                    1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "orientacion".

print(f"Valores presentes en el atributo: {datos_pre['orientacion'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['orientacion'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['No especificado' 'Sur' 'Este' 'Norte, Oeste' 'Sur, Este'
#  'norte, sur, este, oeste' 'Oeste' 'Norte, este' 'Este, Oeste' 'Sur, este'
#  'Sur, oeste' 'Norte, Sur, Este, Oeste' 'Norte, Sur' 'Norte'
#  'Norte, oeste' 'Norte, Este' 'Norte, Sur, Este' 'Sur, Oeste' 'Norte, sur'
#  'Este, oeste' 'Sur, Este, Oeste' 'Norte, este, oeste' 'Norte, Sur, Oeste'
#  'este' 'Noroeste' 'norte' 'oeste' 'sur, oeste' 'Norte, sur, este, oeste'
#  'Sur, este, oeste' 'norte, este, oeste' 'norte, sur, este' 'sur, este'
#  'Norte, sur, este' 'norte, este' 'sur' 'Norte, Este, Oeste'
#  'norte, oeste' 'Norte, sur, oeste' 'norte, sur, oeste' 'norte, sur'
#  'este, oeste' 'sur, este, oeste' 'Noreste'
#  'Noreste, Suroeste, Este, Oeste' ' norte, sur, este, oeste']
#
# Conteo de ocurrencias por valor:
# orientacion
# No especificado                   9763
# Sur                               2167
# Este                              1257
# Sur, Este                          904
# Oeste                              831
# Este, Oeste                        569
# Norte                              558
# Norte, Sur, Este, Oeste            499
# Norte, Sur                         421
# Sur, oeste                         280
# Sur, Oeste                         263
# Norte, Este                        239
# Norte, Oeste                       182
# Sur, este                          175
# Norte, sur, este, oeste            151
# Sur, Este, Oeste                   141
# norte, sur, este, oeste            122
# Sur, este, oeste                   108
# Este, oeste                         81
# Norte, oeste                        76
# Norte, este                         60
# Norte, Sur, Este                    59
# sur                                 53
# Norte, Sur, Oeste                   50
# Norte, Este, Oeste                  31
# Norte, sur                          25
# sur, este                           24
# este                                20
# sur, oeste                          18
# norte, sur, este                    16
# este, oeste                         16
# sur, este, oeste                    13
# Norte, este, oeste                  12
# norte, sur                          11
# norte, este, oeste                   8
# Norte, sur, este                     8
# norte                                7
# Norte, sur, oeste                    7
# norte, sur, oeste                    6
# Noreste                              4
# norte, oeste                         4
# oeste                                4
# norte, este                          4
# Noroeste                             3
#  norte, sur, este, oeste             2
# Noreste, Suroeste, Este, Oeste       1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "calefaccion".

print(f"Valores presentes en el atributo: {datos_pre['calefaccion'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_pre['calefaccion'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['No especificado' 'Gas' 'Individual' 'Gas natural' 'Central'
#  'Calefacción central' 'No dispone' 'Calefacción individual: Gas natural'
#  'Calefacción individual' 'Central: Gasoil' 'No dispone de calefacción'
#  'Eléctrica' 'Gasoil' 'Bomba de frío/calor' 'Individual: Gas natural'
#  'Individual: Eléctrica' 'Calefacción central: Gas' 'Central: Gas'
#  'individual' 'central: Gasoil' 'individual: Gas natural' 'No'
#  'Gas propano/butano' 'Individual eléctrica' 'individual: Eléctrica'
#  'Electrica' 'calefacción central' 'individual: gas natural' 'central'
#  'no dispone' 'Gas central' 'bomba de frío/calor'
#  'Individual: Gas propano/butano' 'no especificado' 'Chimenea'
#  'calefacción individual' 'No disponible']
#
# Conteo de ocurrencias por valor:
# calefaccion
# No especificado                        5368
# Gas natural                            4917
# Individual                             2580
# Eléctrica                              1294
# Gas                                     946
# Calefacción central                     731
# Central                                 623
# Bomba de frío/calor                     575
# No dispone                              528
# No dispone de calefacción               484
# Calefacción individual                  299
# Gasoil                                  280
# Gas propano/butano                      156
# Individual: Gas natural                 115
# Individual: Eléctrica                    98
# individual                               69
# No                                       60
# Central: Gasoil                          47
# Individual eléctrica                     17
# calefacción central                      13
# Calefacción individual: Gas natural      11
# Central: Gas                              9
# Calefacción central: Gas                  7
# individual: Gas natural                   7
# individual: Eléctrica                     2
# central: Gasoil                           2
# central                                   2
# bomba de frío/calor                       2
# Chimenea                                  2
# calefacción individual                    2
# Electrica                                 1
# individual: gas natural                   1
# no dispone                                1
# Gas central                               1
# Individual: Gas propano/butano            1
# no especificado                           1
# No disponible                             1
# Name: count, dtype: int64
