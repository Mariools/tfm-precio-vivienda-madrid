# %%
#Se importan las librerias a utilizar

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import chardet

#Carga de datos ADJUSTED

with open("CasasEnVenta_Madrid_VarsAdjusted.csv", "rb") as f:
    result = chardet.detect(f.read())
    encoding_detected = result["encoding"]

datos_adjusted = pd.read_csv("CasasEnVenta_Madrid_VarsAdjusted.csv", encoding=encoding_detected, sep=';', index_col='id')
print(datos_adjusted.head(5))
# Out:
#      precio tipo_vivienda  metros_cuadrados_totales  metros_cuadrados_utiles  \
# id
# 1    650000          Piso                        78                       78
# 2    525000          Piso                        70                       62
# 3    795000          Piso                       127                      113
# 4   3650000          Piso                       304                      290
# 5   5100000         Ático                       310                      270
#
#    numero_baNos  numero_habitaciones                    estado  \
# id
# 1             1                    2  Segunda mano/buen estado
# 2             1                    1  Segunda mano/buen estado
# 3             2                    5  Segunda mano/buen estado
# 4             5                    4  Segunda mano/buen estado
# 5             5                    4  Segunda mano/buen estado
#
#    tipo_urbanizacion planta  interior  ...          terraza balcon jardin  \
# id                                     ...
# 1           Edificio      2  Exterior  ...               No     No     No
# 2           Edificio      4  Exterior  ...               No     Si     No
# 3           Edificio      4  Exterior  ...               Si     Si     No
# 4           Edificio      5  Exterior  ...  No especificado     Si     No
# 5           Edificio      6  Exterior  ...               Si     No     No
#
#            armarios padel aire_acondicionado                   calefaccion  \
# id
# 1   No especificado    No    No especificado               No especificado
# 2   No especificado    No    No especificado               No especificado
# 3                Si    No    No especificado               No especificado
# 4                Si    No                 Si  Calefacción Individual - Gas
# 5                Si    No                 Si        Calefacción Individual
#
#    postal_code geohash_6 municipio
# id
# 1        28010    ezjq5b    Madrid
# 2        28003    ezjq5c    Madrid
# 3        28003    ezjq5e    Madrid
# 4        28010    ezjq5b    Madrid
# 5        28008    ezjmgq    Madrid
#
# [5 rows x 26 columns]

# %% [markdown]
# Como propuesta de calidad y gestión de datos, se han establecido los siguientes análisis para cada dataset:
#
# **0) Registro de meta-datos del dataset.**
#
# -Los tipos de datos por atributo.
#
# -El rango de valores que presenta.
#
# -Algunas características de los valores.
#
# -Dominio impuesto para cada atributo.
#
# **1) Evaluación de valores nulos.**
#
# **2) Evaluación de formato válido.**
#
# **3) Valores ajustados a los rangos del dominio.**
#
# **4) Claves únicas.**
#
# **5) Integridad referencial.**
#
# **6) Cumplimiento de reglas en valores.**

# %% [markdown]
# ## Análisis Datos Adjusted
#
# **0) Registro de meta-datos del dataset.**
#
# Se usa el método .info() para obtener datos crudos sobre los atributos del dataset y su contenido.

# %%
# Vista de los tipos de datos y el tamaño del dataset (filas/registros y columnas/atributos).

datos_adjusted.info()

print("-------------------------------------")
print(f"Cantidad de filas: {datos_adjusted.shape[0]}")
print(f"Cantidad de columnas: {datos_adjusted.shape[1]}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19253 entries, 1 to 19444
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   precio                    19253 non-null  int64
#  1   tipo_vivienda             19253 non-null  object
#  2   metros_cuadrados_totales  19253 non-null  int64
#  3   metros_cuadrados_utiles   19253 non-null  int64
#  4   numero_baNos              19253 non-null  object
#  5   numero_habitaciones       19253 non-null  int64
#  6   estado                    19253 non-null  object
#  7   tipo_urbanizacion         19253 non-null  object
#  8   planta                    19253 non-null  object
#  9   interior                  19253 non-null  object
#  10  orientacion               19253 non-null  object
#  11  aNo_contruccion           19253 non-null  object
#  12  ascensor                  19253 non-null  object
#  13  piscina                   19253 non-null  object
#  14  trastero                  19253 non-null  object
#  15  garaje                    19253 non-null  object
#  16  terraza                   19253 non-null  object
#  17  balcon                    19253 non-null  object
#  18  jardin                    19253 non-null  object
#  19  armarios                  19253 non-null  object
#  20  padel                     19253 non-null  object
#  21  aire_acondicionado        19253 non-null  object
#  22  calefaccion               19253 non-null  object
#  23  postal_code               19253 non-null  int64
#  24  geohash_6                 19253 non-null  object
#  25  municipio                 19253 non-null  object
# dtypes: int64(5), object(21)
# memory usage: 4.0+ MB
# -------------------------------------
# Cantidad de filas: 19253
# Cantidad de columnas: 26

# %% [markdown]
# Para conocer los valores únicos por atributo y su distribución se usan los métodos .unique() y .value_counts()
#
# .unique(): lista las ocurrencias de valores únicos en el atributo.
#
# .value_counts(): por cada valor del atributo muestra la cantidad de filas que registran tal valor.
#
#
# **Tipos nominales (string)**

# %%
print(datos_adjusted.columns)
# Out:
# Index(['precio', 'tipo_vivienda', 'metros_cuadrados_totales',
#        'metros_cuadrados_utiles', 'numero_baNos', 'numero_habitaciones',
#        'estado', 'tipo_urbanizacion', 'planta', 'interior', 'orientacion',
#        'aNo_contruccion', 'ascensor', 'piscina', 'trastero', 'garaje',
#        'terraza', 'balcon', 'jardin', 'armarios', 'padel',
#        'aire_acondicionado', 'calefaccion', 'postal_code', 'geohash_6',
#        'municipio'],
#       dtype='object')

# %%
#Vista de los valores únicos para la variable "tipo_vivienda".

print(f"Valores presentes en el atributo: {datos_adjusted['tipo_vivienda'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['tipo_vivienda'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Piso' 'Ático' 'Dúplex' 'Estudio' 'Loft' 'Chalet' 'Chalet adosado'
#  'Chalet pareado' 'Casa de Pueblo' 'Finca Rústica' 'Sótano']
#
# Conteo de ocurrencias por valor:
# tipo_vivienda
# Piso              12074
# Chalet             4373
# Ático               961
# Dúplex              826
# Estudio             367
# Chalet adosado      293
# Chalet pareado      112
# Casa de Pueblo      111
# Finca Rústica        99
# Loft                 31
# Sótano                6
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "estado".

print(f"Valores presentes en el atributo: {datos_adjusted['estado'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['estado'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Segunda mano/buen estado' 'Segunda mano/para reformar' 'Obra Nueva'
#  'No especificado']
#
# Conteo de ocurrencias por valor:
# estado
# Segunda mano/buen estado      14946
# Segunda mano/para reformar     2458
# Obra Nueva                     1501
# No especificado                 348
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "tipo_urbanizacion".

print(f"Valores presentes en el atributo: {datos_adjusted['tipo_urbanizacion'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.
print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['tipo_urbanizacion'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Edificio' 'Independiente' 'No especificado' 'Urbanización']
#
# Conteo de ocurrencias por valor:
# tipo_urbanizacion
# Edificio           14252
# Independiente       4968
# Urbanización          21
# No especificado       12
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "planta".

print(f"Valores presentes en el atributo: {datos_adjusted['planta'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['planta'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['2' '4' '5' '6' '8' '-1' '1' '12' '3' '9' '7' 'No especificdo' '0' '10'
#  '16' '17' '11' '20' '13' '14' '18' '15' '-2' '19' '24' '22']
#
# Conteo de ocurrencias por valor:
# planta
# 1                 4540
# No especificdo    3250
# 2                 3001
# 0                 2433
# 3                 2191
# 4                 1603
# 5                  885
# 6                  562
# 7                  321
# 8                  121
# 9                  117
# -1                  81
# 10                  53
# 11                  30
# 12                  22
# 13                  15
# 14                   6
# 15                   6
# 16                   3
# -2                   3
# 22                   3
# 17                   2
# 18                   2
# 20                   1
# 19                   1
# 24                   1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "interior".

print(f"Valores presentes en el atributo: {datos_adjusted['interior'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['interior'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['Exterior' 'Interior' 'No especificado']
#
# Conteo de ocurrencias por valor:
# interior
# Exterior           12599
# No especificado     4974
# Interior            1680
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "orientacion".

print(f"Valores presentes en el atributo: {datos_adjusted['orientacion'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['orientacion'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['No especificado' 'Sur' 'Este' 'Norte, Oeste' 'Sur, Este'
#  'Norte, Sur, Este, Oeste' 'Oeste' 'Norte, Este' 'Este, Oeste'
#  'Sur, Oeste' 'Norte, Sur' 'Norte' 'Norte, Sur, Este' 'Sur, Este, Oeste'
#  'Norte, Este, Oeste' 'Norte, Sur, Oeste' 'Noroeste' 'Noreste'
#  'Noreste, Suroeste, Este, Oeste' ' Norte, Sur, Este, Oeste']
#
# Conteo de ocurrencias por valor:
# orientacion
# No especificado                   9763
# Sur                               2220
# Este                              1277
# Sur, Este                         1103
# Oeste                              835
# Norte, Sur, Este, Oeste            772
# Este, Oeste                        666
# Norte                              565
# Sur, Oeste                         561
# Norte, Sur                         457
# Norte, Este                        303
# Norte, Oeste                       262
# Sur, Este, Oeste                   262
# Norte, Sur, Este                    83
# Norte, Sur, Oeste                   63
# Norte, Este, Oeste                  51
# Noreste                              4
# Noroeste                             3
#  Norte, Sur, Este, Oeste             2
# Noreste, Suroeste, Este, Oeste       1
# Name: count, dtype: int64

# %%
#Vista de los valores únicos para la variable "calefaccion".

print(f"Valores presentes en el atributo: {datos_adjusted['calefaccion'].unique()} \n")

#Vista de la cantidad de ocurrencias de cada valor.

print(f"Conteo de ocurrencias por valor:\n{datos_adjusted['calefaccion'].value_counts()}")
# Out:
# Valores presentes en el atributo: ['No especificado' 'Calefacción Individual - Gas' 'Calefacción Individual'
#  'Calefaccion Central' 'Sin Calefaccion' 'Calefaccion Central - Gasoil'
#  'Calefaccion Individual - Electrica' 'Calefacción Individual - Gasoil'
#  'Calefacción Individual - Bomba de frío/calor'
#  'Calefacción Central - Gas' 'Calefacción Individual - Gas propano/butano'
#  'Calefaccion Central - Gas' 'no especificado'
#  'Calefacción Individual - Chimenea']
#
# Conteo de ocurrencias por valor:
# calefaccion
# Calefacción Individual - Gas                    5998
# No especificado                                 5368
# Calefacción Individual                          2950
# Calefaccion Individual - Electrica              1412
# Calefaccion Central                             1369
# Sin Calefaccion                                 1074
# Calefacción Individual - Bomba de frío/calor     577
# Calefacción Individual - Gasoil                  280
# Calefacción Individual - Gas propano/butano      156
# Calefaccion Central - Gasoil                      49
# Calefacción Central - Gas                         16
# Calefacción Individual - Chimenea                  2
# Calefaccion Central - Gas                          1
# no especificado                                    1
# Name: count, dtype: int64
